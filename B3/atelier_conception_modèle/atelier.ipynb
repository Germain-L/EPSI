# %%
import pandas as pd

# %%
df = pd.read_csv("fr-esr-fete-de-la-science-18.csv", sep=";", encoding="utf-8")

# %%
df
# Out:
#              dates                                          selection  \
# 0     [2018-10-12]     Provence-Alpes-Côte d'Azur>Vaucluse>Carpentras
# 1     [2018-10-06]             Provence-Alpes-Côte d'Azur>Var>Cabasse
# 2     [2018-10-14]    Provence-Alpes-Côte d'Azur>Alpes-Maritimes>Nice
# 3     [2018-10-17]  Provence-Alpes-Côte d'Azur>Alpes-Maritimes>Ant...
# 4     [2018-10-06]      Occitanie>Pyrénées-Orientales>Banyuls-sur-Mer
# ...            ...                                                ...
# 6360  [2018-10-11]        Nouvelle-Aquitaine>Deux-Sèvres>Saint-Varent
# 6361  [2018-10-11]              Nouvelle-Aquitaine>Charente>Angoulême
# 6362  [2018-10-11]                Nouvelle-Aquitaine>Gironde>Bordeaux
# 6363  [2018-10-11]            Nouvelle-Aquitaine>Haute-Vienne>Limoges
# 6364  [2018-10-12]              Nouvelle-Aquitaine>Charente>Angoulême
#
#      identifiant                                           titre_fr  \
# ...

# %%
# Print col name and check if values are single or multiple (separated by a comma or a semicolon)
# print col_name = single or multiple
# print the value that is multiple
for col in df.columns:
    if df[col].str.contains(";").any():
        print(col, "= multiple")
    else:
        print(col, "= single")
# Out:
# dates = single
# selection = single
# identifiant = single
# titre_fr = multiple
# description_fr = multiple
# description_longue_fr = multiple
# detail_des_conditions_fr = multiple
# description_longue_html_fr = multiple
# type_d_animation = single
# mots_cles_fr = multiple
# image = single
# apercu = single
# image_source = single
# derniere_mise_a_jour = single
# resume_horaires_fr = multiple
# horaires_detailles_fr = single
# resume_dates_fr = single
# thematiques = multiple
# publics_concernes = single
# lien_d_inscription = multiple
# accessibilite_fr = single
# age_minimum = single
# age_maximum = single
# en_une = single
# statut = single
# lien = single
# identifiant_du_lieu = single
# nom_du_lieu = multiple
# adresse = multiple
# code_postal = single
# ville = single
# arrondissement = single
# departement = single
# region = single
# pays = single
# image_du_lieu = single
# telephone_du_lieu = single
# site_web_du_lieu = multiple
# tags_du_lieu = single
# ...

# %%
# Out:
# dates = single
# selection = single
# identifiant = single
# titre_fr = multiple
# 1         Tous en boîte, si les animaux m'étaient classés
# 5         Soirée contes, la mythologie des constellations
# 9       Venez découvrir le déplacement des êtres vivan...
# 28      MéliMélo, Démêlez le "vrai du faux" sur la nat...
# 29      La caméra infra-rouge, un outil pluridisciplin...
#                               ...
# 6320                        Un flipbook, s'il vous plaît!
# 6326    Les insectes comestibles, une révolution agric...
# 6335    Marc Michel Rey, un libraire au siècle des Lum...
# 6341                  Le Stop-Motion, clic, c’est parti !
# 6347    Travaux de chercheurs - L’intelligence artific...
# Name: titre_fr, Length: 811, dtype: object
# description_fr = multiple
# 1       La classification du vivant, un autre regard s...
# 2       Dans le cadre de la fête de la science, les vé...
# 5       A l'écoute d'histoires, à l'écoute de nos émot...
# ...
